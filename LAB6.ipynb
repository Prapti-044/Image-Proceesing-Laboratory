# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img_bgr = cv2.imread('lenna.png')
img_hsv = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2HSV)
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
img_hsi = img_hsv.copy()
img_hsi = img_rgb.mean(axis=2)


print(img_rgb.shape)
plt.imshow(img_rgb);
# Out:
# (512, 512, 3)

# %%
a = np.array([[[1, 2], [3, 4],[5,6 ]], [[4, 3], [42, 42], [42, 54]]])

print(a)
# Out:
# [[[ 1  2]
#   [ 3  4]
#   [ 5  6]]
#
#  [[ 4  3]
#   [42 42]
#   [42 54]]]

# %%
img_red = img.copy()
img_red[:, :, 1] = 0
img_red[:, :, 2] = 0

cv2.

img_green = img.copy()
img_green[:, :, 0] = 0
img_green[:, :, 2] = 0

img_blue = img.copy()
img_blue[:, :, 0] = 0
img_blue[:, :, 1] = 0

plt.figure(figsize=(30, 10))
plt.subplot(131)
plt.imshow(img_red);

plt.subplot(132)
plt.imshow(img_green);

plt.subplot(133)
plt.imshow(img_blue);

# %%
img_V = img_hsv[:, :, 2]

plt.imshow(img_V)

# %%
img_V_equ = cv2.equalizeHist(img_V)

img_new = cv2.merge((img_hsv[:, :, 0], img_hsv[:, :, 1], img_V_equ))

img_ret = cv2.cvtColor(new_img, cv2.COLOR_HSV2RGB)

plt.imshow(img_ret)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-35-87b8a7983652> in <module>
#       3 img_new = cv2.merge((img_hsv[:, :, 0], img_hsv[:, :, 1], img_V_equ))
#       4 img_new2 = img_V_equ.copy()
# ----> 5 img_new2[:, :, 2] = img_V_equ
#       6
#       7 print((img_new-img_new2).sum())
#
# IndexError: too many indices for array
